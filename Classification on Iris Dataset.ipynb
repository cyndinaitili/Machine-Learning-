# %% [markdown]
# Classification on Iris Dataset

# %%
import pandas as pd

# %%
iris = pd.read_csv("E:/Data Science/iris.csv", index_col=0)
iris.head(3)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris["Species"].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
iris.boxplot(["SepalLengthCm","SepalWidthCm","PetalWidthCm"])

# %%
import numpy as np
from scipy import stats

z = np.abs(stats.zscore(iris._get_numeric_data()))
outlier = iris[(z < 3).all(axis = 1)]
print(outlier.shape)
# Out:
# (149, 5)

# %%
pd_outlier = pd.DataFrame([])
pd_outlier["Notes"] = ["Not Outlier","Outlier"]
pd_outlier["Number of Observations"] = [outlier.shape[0], iris.shape[0]-outlier.shape[0]]
pd_outlier
# Out:
#          Notes  Number of Observations
# 0  Not Outlier                     149
# 1      Outlier                       1

# %%
import seaborn as sns

sns.set(style = "white")
plot = sns.barplot(x = "Notes",y = "Number of Observations", data = pd_outlier)

rects = plot.patches
labels = pd_outlier["Number of Observations"]
for rect, label in zip(rects, labels):
    height = rect.get_height()
    plot.text(rect.get_x() + rect.get_width()/2,height + 0.2, label, ha = 'center', va = 'bottom', fontsize = 10)

# %%
features
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Id
# 1              5.1           3.5            1.4           0.2
# 2              4.9           3.0            1.4           0.2
# 3              4.7           3.2            1.3           0.2
# 4              4.6           3.1            1.5           0.2
# 5              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 146            6.7           3.0            5.2           2.3
# 147            6.3           2.5            5.0           1.9
# 148            6.5           3.0            5.2           2.0
# 149            6.2           3.4            5.4           2.3
# 150            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
from sklearn import preprocessing

features = iris.iloc[:,0:4]
features_normalized = preprocessing.normalize(features, norm='l2')
features_normalized = pd.DataFrame(features_normalized, columns = features.columns.tolist())
features_normalized
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0         0.803773      0.551609       0.220644      0.031521
# 1         0.828133      0.507020       0.236609      0.033801
# 2         0.805333      0.548312       0.222752      0.034269
# 3         0.800030      0.539151       0.260879      0.034784
# 4         0.790965      0.569495       0.221470      0.031639
# ..             ...           ...            ...           ...
# 145       0.721557      0.323085       0.560015      0.247699
# 146       0.729654      0.289545       0.579090      0.220054
# 147       0.716539      0.330710       0.573231      0.220474
# 148       0.674671      0.369981       0.587616      0.250281
# 149       0.690259      0.350979       0.596665      0.210588
#
# [150 rows x 4 columns]

# %%
features_normalized.boxplot(["SepalLengthCm","PetalLengthCm","PetalWidthCm"])

# %%
iris.boxplot(["SepalLengthCm","SepalWidthCm","PetalWidthCm"])

# %%
z = np.abs(stats.zscore(features_normalized._get_numeric_data()))
outlier = features_normalized[(z < 3).all(axis = 1)]
print(outlier.shape)
# Out:
# (150, 4)

# %%
pd_outlier = pd.DataFrame([])
pd_outlier["Notes"] = ["Not Outlier","Outlier"]
pd_outlier["Number of Observations"] = [outlier.shape[0], iris.shape[0]-outlier.shape[0]]
pd_outlier
# Out:
#          Notes  Number of Observations
# 0  Not Outlier                     150
# 1      Outlier                       0

# %%
import seaborn as sns

sns.set(style = "white")
plot = sns.barplot(x = "Notes",y = "Number of Observations", data = pd_outlier)

rects = plot.patches
labels = pd_outlier["Number of Observations"]
for rect, label in zip(rects, labels):
    height = rect.get_height()
    plot.text(rect.get_x() + rect.get_width()/2,height + 0.2, label, ha = 'center', va = 'bottom', fontsize = 10)

# %%
from sklearn.model_selection import train_test_split

x = features_normalized
y = iris.iloc[:,-1]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (120,)
# (30, 4)
# (30,)

# %%
x_train.head(3)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 22       0.775771      0.607125       0.168646      0.033729
# 15       0.773811      0.597328       0.203635      0.054303
# 65       0.769454      0.356016       0.505313      0.160782

# %% [markdown]
# Classification using K-Nearest nNeighbor

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

model = KNeighborsClassifier(n_neighbors = 3, weights = 'uniform', p = 2)
model.fit(x_train, y_train)
y_predict = model.predict(x_test)

cm = confusion_matrix(y_predict, y_test)
accuracy = accuracy_score(y_predict, y_test)

print(cm)
print('\n')
print('The accuracy of the KNN is:', accuracy)
# Out:
# [[10  0  0]
#  [ 0  9  1]
#  [ 0  0 10]]
#
#
# The accuracy of the KNN is: 0.9666666666666667

# %% [markdown]
# Tuning Parameter for K-Nearest Neighbor with GridSearch

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

model = KNeighborsClassifier()
scorer = make_scorer(accuracy_score, greater_is_better = True)
parameters = [{'n_neighbors':[3,5,7,9,11,13,15,17],
              'weights' :['uniform','distance'],
              'p' : [1,2]}]

model_gscv = GridSearchCV(model, param_grid = parameters, scoring = scorer, cv = 5)
model_gscv.fit(x, y)
print('Best Parameter :', model_gscv.best_params_)
print('Best Score     :', model_gscv.best_score_)
# Out:
# Best Parameter : {'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# Best Score     : 0.9800000000000001

# %%
cv_result = pd.DataFrame.from_dict(model_gscv.cv_results_)
cv_result
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.006556  6.174079e-03         0.005967    1.251687e-03
# 1        0.003178  3.985220e-04         0.002192    4.110576e-04
# 2        0.003571  7.810618e-04         0.004178    3.941340e-04
# 3        0.003576  4.730779e-04         0.002583    4.864375e-04
# 4        0.003164  4.046574e-04         0.005577    1.356827e-03
# 5        0.002980  6.162843e-04         0.002191    3.746841e-04
# 6        0.003177  3.989697e-04         0.004967    2.017421e-06
# 7        0.003164  3.855782e-04         0.002597    7.933677e-04
# 8        0.002994  1.663513e-05         0.004357    4.700500e-04
# 9        0.002995  6.387727e-04         0.002177    3.991930e-04
# 10       0.002982  1.813236e-06         0.004169    3.959207e-04
# 11       0.002781  3.970868e-04         0.002391    4.956356e-04
# 12       0.003179  3.951369e-04         0.004562    7.833971e-04
# 13       0.002979  1.466613e-06         0.002185    3.972539e-04
# 14       0.003172  4.016974e-04         0.003973    3.989506e-07
# 15       0.002994  1.793402e-05         0.002568    4.908825e-04
# 16       0.002980  3.420621e-06         0.004767    7.527081e-04
# 17       0.003178  3.971579e-04         0.003378    1.347755e-03
# 18       0.003378  4.882692e-04         0.005562    4.707695e-04
# 19       0.003378  4.865142e-04         0.005165    4.370284e-03
# 20       0.004582  2.226798e-03         0.004358    4.969793e-04
# 21       0.003179  3.968240e-04         0.004172    2.906581e-03
# 22       0.002781  7.433072e-04         0.004768    3.969914e-04
# 23       0.002980  6.325960e-07         0.002782    3.970629e-04
# 24       0.002979  6.283392e-04         0.004768    7.431035e-04
# 25       0.004172  2.025868e-03         0.002782    7.436257e-04
# 26       0.004172  1.317899e-03         0.009337    3.800632e-03
# 27       0.007153  2.908648e-03         0.004171    1.317391e-03
# 28       0.009733  4.760403e-03         0.010132    4.590572e-03
# 29       0.003774  7.425571e-04         0.003377    1.012847e-03
# 30       0.003178  3.973962e-04         0.004768    3.975630e-04
# 31       0.002980  5.091228e-07         0.002583    4.862028e-04
#
#    param_n_neighbors param_p param_weights  \
# 0                  3       1       uniform
# 1                  3       1      distance
# 2                  3       2       uniform
# 3                  3       2      distance
# 4                  5       1       uniform
# 5                  5       1      distance
# 6                  5       2       uniform
# 7                  5       2      distance
# 8                  7       1       uniform
# 9                  7       1      distance
# 10                 7       2       uniform
# 11                 7       2      distance
# 12                 9       1       uniform
# 13                 9       1      distance
# 14                 9       2       uniform
# 15                 9       2      distance
# 16                11       1       uniform
# 17                11       1      distance
# 18                11       2       uniform
# 19                11       2      distance
# 20                13       1       uniform
# 21                13       1      distance
# 22                13       2       uniform
# 23                13       2      distance
# 24                15       1       uniform
# 25                15       1      distance
# 26                15       2       uniform
# 27                15       2      distance
# 28                17       1       uniform
# 29                17       1      distance
# 30                17       2       uniform
# 31                17       2      distance
#
#                                                params  split0_test_score  \
# 0    {'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}                1.0
# 1   {'n_neighbors': 3, 'p': 1, 'weights': 'distance'}                1.0
# 2    {'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}                1.0
# 3   {'n_neighbors': 3, 'p': 2, 'weights': 'distance'}                1.0
# 4    {'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}                1.0
# 5   {'n_neighbors': 5, 'p': 1, 'weights': 'distance'}                1.0
# 6    {'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}                1.0
# 7   {'n_neighbors': 5, 'p': 2, 'weights': 'distance'}                1.0
# 8    {'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}                1.0
# 9   {'n_neighbors': 7, 'p': 1, 'weights': 'distance'}                1.0
# 10   {'n_neighbors': 7, 'p': 2, 'weights': 'uniform'}                1.0
# 11  {'n_neighbors': 7, 'p': 2, 'weights': 'distance'}                1.0
# 12   {'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}                1.0
# 13  {'n_neighbors': 9, 'p': 1, 'weights': 'distance'}                1.0
# 14   {'n_neighbors': 9, 'p': 2, 'weights': 'uniform'}                1.0
# 15  {'n_neighbors': 9, 'p': 2, 'weights': 'distance'}                1.0
# 16  {'n_neighbors': 11, 'p': 1, 'weights': 'uniform'}                1.0
# 17  {'n_neighbors': 11, 'p': 1, 'weights': 'distan...                1.0
# 18  {'n_neighbors': 11, 'p': 2, 'weights': 'uniform'}                1.0
# 19  {'n_neighbors': 11, 'p': 2, 'weights': 'distan...                1.0
# 20  {'n_neighbors': 13, 'p': 1, 'weights': 'uniform'}                1.0
# 21  {'n_neighbors': 13, 'p': 1, 'weights': 'distan...                1.0
# 22  {'n_neighbors': 13, 'p': 2, 'weights': 'uniform'}                1.0
# 23  {'n_neighbors': 13, 'p': 2, 'weights': 'distan...                1.0
# 24  {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'